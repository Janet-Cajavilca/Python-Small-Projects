# %% [markdown]
# # Leap Year Test
#
# - "A leap year (also known as an intercalary year or bissextile year) is a calendar year that contains an additional day". ([Source, Wikipedia](https://en.wikipedia.org/wiki/Leap_year))
# - We can see in the following diagram how to test if a given year is a leap year.([Source, w3resource.com](https://www.w3resource.com/javascript-exercises/javascript-basic-exercise-6.php))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Ask for the year to check

year = int(input("Which year do you want to check? "))
# Out:
# Which year do you want to check? 2024

# %%
# Test if it's a leap year using if-else statements

if year %4 == 0: 
 if year % 100 ==0:
   if year % 400 == 0:
     print (f"{year} is a leap year.")
   else:
     print (f"{year} is not a leap year")
 else:
   print ( f"{year} is a leap year.")

else:
  print (f"{year} is not a leap year.")
# Out:
# 2024 is a leap year.
